# %%
import sys, os

src = r"C:\Users\user\Desktop\Coding mo\AutoML proj1\task 1\AutoML Project Molham\src" # copy the location of the folder that has paths.py file using (ctrl + shift + C ) and paste it here    
sys.path.append(src)

from paths import *

get_paths()

sys.path.append(SRC_PATH)

from paths import *

# %%
print("all automl reports are built in RUNTIME_MEMORY_TASK1_PATH & RUNTIME_MEMORY_TASK3_PATH")
print("all boosting reports are built in RUNTIME_MEMORY_TASK2_BOOSTINGS_PATH & RUNTIME_MEMORY_TASK2_BOOSTINGS_TUNED_PATH")
# Out:
# all automl reports are built in RUNTIME_MEMORY_TASK1_PATH & RUNTIME_MEMORY_TASK3_PATH
# all boosting reports are built in RUNTIME_MEMORY_TASK2_BOOSTINGS_PATH & RUNTIME_MEMORY_TASK2_BOOSTINGS_TUNED_PATH
